# %%
# import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes into a list 
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities 
cities = []
# Identify the nearest city for each longitude and latitude combination
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list
    if city not in cities: 
        cities.append(city)
# print the city length to confirm sufficient count
len(cities)
# Out:
# 762

# %%
# Import the requests library
import requests
# import the API key
from config import weather_api_key

# %%
import time

# %%
# Create a base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data 
city_data = []
# Print the beginning of the logging 
print("Beginning Data Retrieval   ")
print("---------------------------")

# create counters 
record_count = 1
set_count = 1

# Loop through all of the cities in our list 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL for each city 
    city_url = url + "&q=" + city.replace(" ", "+")

     # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')

    # Add 1 to the record count 
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 2 of Set 1 | tazovskiy
# Processing Record 3 of Set 1 | port alfred
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | lodwar
# Processing Record 7 of Set 1 | ugoofaaru
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | correntina
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | saint-philippe
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | bowen
# Processing Record 15 of Set 1 | hobart
# Processing Record 16 of Set 1 | narsaq
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | jamestown
# Processing Record 19 of Set 1 | luwingu
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | canberra
# Processing Record 26 of Set 1 | mitsamiouli
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | kurchum
# Processing Record 29 of Set 1 | college
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | vaini
# Processing Record 32 of Set 1 | tshela
# Processing Record 33 of Set 1 | tasiilaq
# Processing Record 34 of Set 1 | mercedes
# Processing Record 35 of Set 1 | lompoc
# Processing Record 36 of Set 1 | puerto leguizamo
# Processing Record 37 of Set 1 | punta arenas
# Processing Record 38 of Set 1 | dikson
# Processing Record 39 of Set 1 | brovary
# Processing Record 40 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | mahebourg
# Processing Record 46 of Set 1 | acapulco
# Processing Record 47 of Set 1 | cabo san lucas
# Processing Record 48 of Set 1 | hendijan
# City not found. Skipping...
# Processing Record 49 of Set 1 | pontes e lacerda
# Processing Record 50 of Set 1 | hithadhoo
# Processing Record 1 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 2 of Set 2 | pascagoula
# Processing Record 3 of Set 2 | rawson
# Processing Record 4 of Set 2 | seoul
# Processing Record 5 of Set 2 | jesi
# Processing Record 6 of Set 2 | abu samrah
# Processing Record 7 of Set 2 | namatanai
# Processing Record 8 of Set 2 | bredasdorp
# Processing Record 9 of Set 2 | barcelos
# Processing Record 10 of Set 2 | lorengau
# Processing Record 11 of Set 2 | novyy urgal
# Processing Record 12 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 13 of Set 2 | bilma
# Processing Record 14 of Set 2 | manbij
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | nerchinskiy zavod
# Processing Record 17 of Set 2 | chuy
# Processing Record 18 of Set 2 | pilar
# Processing Record 19 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 20 of Set 2 | karratha
# Processing Record 21 of Set 2 | los llanos de aridane
# Processing Record 22 of Set 2 | yar-sale
# Processing Record 23 of Set 2 | itigi
# Processing Record 24 of Set 2 | souillac
# Processing Record 25 of Set 2 | margate
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | kaitangata
# Processing Record 29 of Set 2 | east london
# Processing Record 30 of Set 2 | shimoda
# Processing Record 31 of Set 2 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 2 | aleksandrov gay
# Processing Record 33 of Set 2 | luis correia
# Processing Record 34 of Set 2 | puerto colombia
# Processing Record 35 of Set 2 | faanui
# Processing Record 36 of Set 2 | westport
# Processing Record 37 of Set 2 | kavaratti
# Processing Record 38 of Set 2 | georgetown
# Processing Record 39 of Set 2 | marawi
# Processing Record 40 of Set 2 | codrington
# Processing Record 41 of Set 2 | ascension
# Processing Record 42 of Set 2 | ahipara
# Processing Record 43 of Set 2 | kleck
# City not found. Skipping...
# Processing Record 44 of Set 2 | cockburn town
# Processing Record 45 of Set 2 | norman wells
# Processing Record 46 of Set 2 | havre-saint-pierre
# Processing Record 47 of Set 2 | yellowknife
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | bluff
# Processing Record 50 of Set 2 | malwan
# City not found. Skipping...
# Processing Record 1 of Set 3 | yaring
# Processing Record 2 of Set 3 | port elizabeth
# Processing Record 3 of Set 3 | anadyr
# Processing Record 4 of Set 3 | baruun-urt
# Processing Record 5 of Set 3 | meadow lake
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | sarkand
# Processing Record 8 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 3 | torbay
# Processing Record 10 of Set 3 | antofagasta
# Processing Record 11 of Set 3 | pouebo
# Processing Record 12 of Set 3 | puerto ayora
# Processing Record 13 of Set 3 | cascais
# Processing Record 14 of Set 3 | ponta do sol
# Processing Record 15 of Set 3 | livingston
# Processing Record 16 of Set 3 | victoria
# Processing Record 17 of Set 3 | kushima
# Processing Record 18 of Set 3 | cabra
# Processing Record 19 of Set 3 | tiksi
# Processing Record 20 of Set 3 | sarlat-la-caneda
# Processing Record 21 of Set 3 | kodiak
# Processing Record 22 of Set 3 | high level
# Processing Record 23 of Set 3 | mahajanga
# Processing Record 24 of Set 3 | vila franca do campo
# Processing Record 25 of Set 3 | udachnyy
# Processing Record 26 of Set 3 | kamaishi
# Processing Record 27 of Set 3 | monte alegre
# Processing Record 28 of Set 3 | nantucket
# Processing Record 29 of Set 3 | iquitos
# Processing Record 30 of Set 3 | mataura
# Processing Record 31 of Set 3 | eydhafushi
# Processing Record 32 of Set 3 | bambous virieux
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | avarua
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | pitimbu
# Processing Record 37 of Set 3 | bud
# Processing Record 38 of Set 3 | mount gambier
# Processing Record 39 of Set 3 | hamilton
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | sanmenxia
# Processing Record 42 of Set 3 | kruisfontein
# Processing Record 43 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 44 of Set 3 | tavda
# Processing Record 45 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 46 of Set 3 | nikolskoye
# Processing Record 47 of Set 3 | zyryanka
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | roma
# Processing Record 50 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 1 of Set 4 | intipuca
# Processing Record 2 of Set 4 | cherskiy
# Processing Record 3 of Set 4 | catamarca
# Processing Record 4 of Set 4 | curuca
# Processing Record 5 of Set 4 | tornio
# Processing Record 6 of Set 4 | kazalinsk
# City not found. Skipping...
# Processing Record 7 of Set 4 | north bend
# Processing Record 8 of Set 4 | khilok
# Processing Record 9 of Set 4 | sur
# Processing Record 10 of Set 4 | cherdyn
# Processing Record 11 of Set 4 | coquimbo
# Processing Record 12 of Set 4 | bathsheba
# Processing Record 13 of Set 4 | tadepalle
# Processing Record 14 of Set 4 | saiha
# Processing Record 15 of Set 4 | san rafael
# Processing Record 16 of Set 4 | dingle
# Processing Record 17 of Set 4 | sheridan
# Processing Record 18 of Set 4 | svetlogorsk
# Processing Record 19 of Set 4 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 4 | dali
# Processing Record 21 of Set 4 | timaru
# Processing Record 22 of Set 4 | kuandian
# Processing Record 23 of Set 4 | elizabeth city
# Processing Record 24 of Set 4 | saint-augustin
# Processing Record 25 of Set 4 | grindavik
# Processing Record 26 of Set 4 | viesca
# Processing Record 27 of Set 4 | bengkulu
# Processing Record 28 of Set 4 | arlit
# Processing Record 29 of Set 4 | sao filipe
# Processing Record 30 of Set 4 | portland
# Processing Record 31 of Set 4 | praia da vitoria
# Processing Record 32 of Set 4 | horodyshche
# Processing Record 33 of Set 4 | san quintin
# Processing Record 34 of Set 4 | sitka
# Processing Record 35 of Set 4 | namie
# Processing Record 36 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 4 | emerald
# Processing Record 38 of Set 4 | itapuranga
# Processing Record 39 of Set 4 | abaza
# Processing Record 40 of Set 4 | pyay
# Processing Record 41 of Set 4 | lebu
# Processing Record 42 of Set 4 | khomeynishahr
# City not found. Skipping...
# Processing Record 43 of Set 4 | birao
# Processing Record 44 of Set 4 | nanortalik
# Processing Record 45 of Set 4 | tubruq
# City not found. Skipping...
# Processing Record 46 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 47 of Set 4 | hofn
# Processing Record 48 of Set 4 | vestmannaeyjar
# Processing Record 49 of Set 4 | shinpokh
# Processing Record 50 of Set 4 | yarkovo
# Processing Record 1 of Set 5 | inhambane
# Processing Record 2 of Set 5 | castro
# Processing Record 3 of Set 5 | mount isa
# Processing Record 4 of Set 5 | conde
# Processing Record 5 of Set 5 | rio cuarto
# Processing Record 6 of Set 5 | dargaville
# Processing Record 7 of Set 5 | skuodas
# Processing Record 8 of Set 5 | yanam
# Processing Record 9 of Set 5 | coihaique
# Processing Record 10 of Set 5 | faya
# Processing Record 11 of Set 5 | yangambi
# Processing Record 12 of Set 5 | cidreira
# Processing Record 13 of Set 5 | walvis bay
# Processing Record 14 of Set 5 | wanaka
# Processing Record 15 of Set 5 | emba
# Processing Record 16 of Set 5 | esso
# Processing Record 17 of Set 5 | saint george
# Processing Record 18 of Set 5 | tual
# Processing Record 19 of Set 5 | half moon bay
# Processing Record 20 of Set 5 | corning
# Processing Record 21 of Set 5 | yambio
# Processing Record 22 of Set 5 | salihli
# Processing Record 23 of Set 5 | havoysund
# Processing Record 24 of Set 5 | nipawin
# Processing Record 25 of Set 5 | ilulissat
# Processing Record 26 of Set 5 | sibolga
# Processing Record 27 of Set 5 | bolshaya yelkhovka
# City not found. Skipping...
# Processing Record 28 of Set 5 | palmer
# Processing Record 29 of Set 5 | touros
# Processing Record 30 of Set 5 | igrim
# Processing Record 31 of Set 5 | tolyatti
# Processing Record 32 of Set 5 | belyy yar
# Processing Record 33 of Set 5 | thompson
# Processing Record 34 of Set 5 | severo-kurilsk
# Processing Record 35 of Set 5 | provideniya
# Processing Record 36 of Set 5 | pokhara
# Processing Record 37 of Set 5 | burica
# City not found. Skipping...
# Processing Record 38 of Set 5 | lavrentiya
# Processing Record 39 of Set 5 | dudinka
# Processing Record 40 of Set 5 | pisco
# Processing Record 41 of Set 5 | tuktoyaktuk
# Processing Record 42 of Set 5 | guangyuan
# Processing Record 43 of Set 5 | kalianget
# Processing Record 44 of Set 5 | port augusta
# Processing Record 45 of Set 5 | pangnirtung
# Processing Record 46 of Set 5 | beringovskiy
# Processing Record 47 of Set 5 | tabou
# Processing Record 48 of Set 5 | port angeles
# Processing Record 49 of Set 5 | synya
# Processing Record 50 of Set 5 | airai
# Processing Record 1 of Set 6 | lagoa
# Processing Record 2 of Set 6 | valparaiso
# Processing Record 3 of Set 6 | maroantsetra
# Processing Record 4 of Set 6 | chaozhou
# Processing Record 5 of Set 6 | aasiaat
# Processing Record 6 of Set 6 | zhangye
# Processing Record 7 of Set 6 | mokhsogollokh
# Processing Record 8 of Set 6 | hervey bay
# Processing Record 9 of Set 6 | hue
# Processing Record 10 of Set 6 | vila velha
# Processing Record 11 of Set 6 | turukhansk
# Processing Record 12 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 13 of Set 6 | vao
# Processing Record 14 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 15 of Set 6 | ancud
# Processing Record 16 of Set 6 | payo
# Processing Record 17 of Set 6 | siwani
# City not found. Skipping...
# Processing Record 18 of Set 6 | buckeye
# Processing Record 19 of Set 6 | iqaluit
# Processing Record 20 of Set 6 | whitianga
# Processing Record 21 of Set 6 | jardim
# Processing Record 22 of Set 6 | marsa matruh
# Processing Record 23 of Set 6 | south daytona
# Processing Record 24 of Set 6 | omsukchan
# Processing Record 25 of Set 6 | altay
# Processing Record 26 of Set 6 | waddan
# Processing Record 27 of Set 6 | pinheiro machado
# Processing Record 28 of Set 6 | sol-iletsk
# Processing Record 29 of Set 6 | muchkapskiy
# Processing Record 30 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 31 of Set 6 | alice town
# Processing Record 32 of Set 6 | kennett
# Processing Record 33 of Set 6 | cayenne
# Processing Record 34 of Set 6 | pasighat
# Processing Record 35 of Set 6 | deputatskiy
# Processing Record 36 of Set 6 | alcaniz
# Processing Record 37 of Set 6 | malazgirt
# Processing Record 38 of Set 6 | axim
# Processing Record 39 of Set 6 | ostersund
# Processing Record 40 of Set 6 | kupang
# Processing Record 41 of Set 6 | along
# Processing Record 42 of Set 6 | rio grande
# Processing Record 43 of Set 6 | port-gentil
# Processing Record 44 of Set 6 | evensk
# Processing Record 45 of Set 6 | olafsvik
# Processing Record 46 of Set 6 | sao joao da barra
# Processing Record 47 of Set 6 | praya
# Processing Record 48 of Set 6 | severodvinsk
# Processing Record 49 of Set 6 | high rock
# Processing Record 50 of Set 6 | tura
# Processing Record 1 of Set 7 | upernavik
# Processing Record 2 of Set 7 | ust-nera
# Processing Record 3 of Set 7 | naze
# Processing Record 4 of Set 7 | babanusah
# City not found. Skipping...
# Processing Record 5 of Set 7 | porto-vecchio
# Processing Record 6 of Set 7 | hami
# Processing Record 7 of Set 7 | garden city
# Processing Record 8 of Set 7 | assiniboia
# Processing Record 9 of Set 7 | geraldton
# Processing Record 10 of Set 7 | viru
# Processing Record 11 of Set 7 | hambantota
# Processing Record 12 of Set 7 | flinders
# Processing Record 13 of Set 7 | tuatapere
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | khani
# Processing Record 16 of Set 7 | hualmay
# Processing Record 17 of Set 7 | pevek
# Processing Record 18 of Set 7 | ixtapa
# Processing Record 19 of Set 7 | corrente
# Processing Record 20 of Set 7 | joshimath
# Processing Record 21 of Set 7 | jiayuguan
# Processing Record 22 of Set 7 | latung
# Processing Record 23 of Set 7 | saldanha
# Processing Record 24 of Set 7 | mar del plata
# Processing Record 25 of Set 7 | krasnoarmeysk
# Processing Record 26 of Set 7 | zhigansk
# Processing Record 27 of Set 7 | razole
# Processing Record 28 of Set 7 | shibarghan
# City not found. Skipping...
# Processing Record 29 of Set 7 | kahului
# Processing Record 30 of Set 7 | mollendo
# Processing Record 31 of Set 7 | talnakh
# Processing Record 32 of Set 7 | jimenez
# Processing Record 33 of Set 7 | jurado
# Processing Record 34 of Set 7 | ayna
# Processing Record 35 of Set 7 | sehithwa
# Processing Record 36 of Set 7 | ust-maya
# Processing Record 37 of Set 7 | bantry
# Processing Record 38 of Set 7 | lesnoy
# Processing Record 39 of Set 7 | sadon
# Processing Record 40 of Set 7 | korla
# Processing Record 41 of Set 7 | keti bandar
# Processing Record 42 of Set 7 | brejo
# Processing Record 43 of Set 7 | mehamn
# Processing Record 44 of Set 7 | ayan
# Processing Record 45 of Set 7 | ewa beach
# Processing Record 46 of Set 7 | preobrazheniye
# Processing Record 47 of Set 7 | logansport
# Processing Record 48 of Set 7 | alofi
# Processing Record 49 of Set 7 | tunxi
# City not found. Skipping...
# Processing Record 50 of Set 7 | safford
# Processing Record 1 of Set 8 | isangel
# Processing Record 2 of Set 8 | klaksvik
# Processing Record 3 of Set 8 | arman
# Processing Record 4 of Set 8 | pochutla
# Processing Record 5 of Set 8 | fonte boa
# Processing Record 6 of Set 8 | san blas
# Processing Record 7 of Set 8 | jining
# Processing Record 8 of Set 8 | yulara
# Processing Record 9 of Set 8 | tonj
# Processing Record 10 of Set 8 | mercaderes
# Processing Record 11 of Set 8 | rathcoole
# Processing Record 12 of Set 8 | victor harbor
# Processing Record 13 of Set 8 | tahe
# Processing Record 14 of Set 8 | svetlaya
# Processing Record 15 of Set 8 | batagay
# Processing Record 16 of Set 8 | port hardy
# Processing Record 17 of Set 8 | murgab
# Processing Record 18 of Set 8 | lufkin
# Processing Record 19 of Set 8 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 8 | rivadavia
# Processing Record 21 of Set 8 | vila
# Processing Record 22 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 23 of Set 8 | puerto escondido
# Processing Record 24 of Set 8 | sijunjung
# Processing Record 25 of Set 8 | maloshuyka
# City not found. Skipping...
# Processing Record 26 of Set 8 | rafaela
# Processing Record 27 of Set 8 | tateyama
# Processing Record 28 of Set 8 | namibe
# Processing Record 29 of Set 8 | ondjiva
# Processing Record 30 of Set 8 | umm jarr
# City not found. Skipping...
# Processing Record 31 of Set 8 | salalah
# Processing Record 32 of Set 8 | alice springs
# Processing Record 33 of Set 8 | ambilobe
# Processing Record 34 of Set 8 | olga
# Processing Record 35 of Set 8 | bar harbor
# Processing Record 36 of Set 8 | xingyi
# Processing Record 37 of Set 8 | galle
# Processing Record 38 of Set 8 | comodoro rivadavia
# Processing Record 39 of Set 8 | lampang
# Processing Record 40 of Set 8 | egvekinot
# Processing Record 41 of Set 8 | kirkenes
# Processing Record 42 of Set 8 | san patricio
# Processing Record 43 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 44 of Set 8 | caravelas
# Processing Record 45 of Set 8 | papara
# Processing Record 46 of Set 8 | katherine
# Processing Record 47 of Set 8 | viedma
# Processing Record 48 of Set 8 | jishou
# Processing Record 49 of Set 8 | umm kaddadah
# Processing Record 50 of Set 8 | buala
# Processing Record 1 of Set 9 | la palma
# Processing Record 2 of Set 9 | okha
# Processing Record 3 of Set 9 | miri
# Processing Record 4 of Set 9 | dekalb
# Processing Record 5 of Set 9 | mounana
# Processing Record 6 of Set 9 | sao felix do xingu
# Processing Record 7 of Set 9 | bandarbeyla
# Processing Record 8 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 9 of Set 9 | mareeba
# Processing Record 10 of Set 9 | altamira
# Processing Record 11 of Set 9 | morecambe
# Processing Record 12 of Set 9 | skibbereen
# Processing Record 13 of Set 9 | ossora
# Processing Record 14 of Set 9 | sakaiminato
# Processing Record 15 of Set 9 | cordoba
# Processing Record 16 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 9 | forssa
# Processing Record 18 of Set 9 | penzance
# Processing Record 19 of Set 9 | bell ville
# Processing Record 20 of Set 9 | middelkerke
# Processing Record 21 of Set 9 | dawei
# Processing Record 22 of Set 9 | leeton
# Processing Record 23 of Set 9 | nishihara
# Processing Record 24 of Set 9 | fortuna
# Processing Record 25 of Set 9 | umm lajj
# Processing Record 26 of Set 9 | aklavik
# Processing Record 27 of Set 9 | oum hadjer
# Processing Record 28 of Set 9 | vardo
# Processing Record 29 of Set 9 | waingapu
# Processing Record 30 of Set 9 | fort walton beach
# Processing Record 31 of Set 9 | araouane
# Processing Record 32 of Set 9 | sile
# Processing Record 33 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 34 of Set 9 | urengoy
# Processing Record 35 of Set 9 | wufeng
# Processing Record 36 of Set 9 | kebemer
# City not found. Skipping...
# Processing Record 37 of Set 9 | tshikapa
# Processing Record 38 of Set 9 | matara
# Processing Record 39 of Set 9 | igarka
# Processing Record 40 of Set 9 | vostok
# Processing Record 41 of Set 9 | kidal
# Processing Record 42 of Set 9 | itarema
# Processing Record 43 of Set 9 | padang
# Processing Record 44 of Set 9 | balkhash
# Processing Record 45 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 46 of Set 9 | gimli
# Processing Record 47 of Set 9 | berbera
# Processing Record 48 of Set 9 | santiago
# Processing Record 49 of Set 9 | bago
# Processing Record 50 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 10 | guerrero negro
# Processing Record 2 of Set 10 | gazanjyk
# Processing Record 3 of Set 10 | iskilip
# Processing Record 4 of Set 10 | kasulu
# Processing Record 5 of Set 10 | paro
# Processing Record 6 of Set 10 | paris
# Processing Record 7 of Set 10 | saint-pierre
# Processing Record 8 of Set 10 | hollister
# Processing Record 9 of Set 10 | chop
# Processing Record 10 of Set 10 | troitskoye
# Processing Record 11 of Set 10 | baiyin
# Processing Record 12 of Set 10 | mastic beach
# Processing Record 13 of Set 10 | krasnoselkup
# Processing Record 14 of Set 10 | lasa
# Processing Record 15 of Set 10 | madona
# Processing Record 16 of Set 10 | kudat
# Processing Record 17 of Set 10 | avera
# Processing Record 18 of Set 10 | yeppoon
# Processing Record 19 of Set 10 | adrar
# Processing Record 20 of Set 10 | binabalian
# Processing Record 21 of Set 10 | esperance
# Processing Record 22 of Set 10 | churapcha
# Processing Record 23 of Set 10 | kungurtug
# Processing Record 24 of Set 10 | acarau
# Processing Record 25 of Set 10 | tautira
# Processing Record 26 of Set 10 | sangar
# Processing Record 27 of Set 10 | darnah
# Processing Record 28 of Set 10 | lazaro cardenas
# Processing Record 29 of Set 10 | alta floresta
# Processing Record 30 of Set 10 | nueva concepcion
# Processing Record 31 of Set 10 | malanje
# Processing Record 32 of Set 10 | ponazyrevo
# Processing Record 33 of Set 10 | manggar
# Processing Record 34 of Set 10 | harnosand
# Processing Record 35 of Set 10 | saint anthony
# Processing Record 36 of Set 10 | kysyl-syr
# Processing Record 37 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 38 of Set 10 | arani
# Processing Record 39 of Set 10 | mlowo
# Processing Record 40 of Set 10 | lata
# Processing Record 41 of Set 10 | pandan
# Processing Record 42 of Set 10 | byron bay
# Processing Record 43 of Set 10 | palenque
# Processing Record 44 of Set 10 | hit
# Processing Record 45 of Set 10 | barentsburg
# City not found. Skipping...
# Processing Record 46 of Set 10 | mentakab
# Processing Record 47 of Set 10 | bethel
# Processing Record 48 of Set 10 | dunedin
# Processing Record 49 of Set 10 | frankfort
# Processing Record 50 of Set 10 | mao
# Processing Record 1 of Set 11 | hvide sande
# Processing Record 2 of Set 11 | escarcega
# Processing Record 3 of Set 11 | alyangula
# Processing Record 4 of Set 11 | kurilsk
# Processing Record 5 of Set 11 | san felipe
# Processing Record 6 of Set 11 | port hueneme
# Processing Record 7 of Set 11 | telimele
# Processing Record 8 of Set 11 | zhanatas
# City not found. Skipping...
# Processing Record 9 of Set 11 | majene
# Processing Record 10 of Set 11 | bagan
# Processing Record 11 of Set 11 | quatre cocos
# Processing Record 12 of Set 11 | omagh
# Processing Record 13 of Set 11 | meulaboh
# Processing Record 14 of Set 11 | sangueya
# Processing Record 15 of Set 11 | nandurbar
# Processing Record 16 of Set 11 | sioux falls
# Processing Record 17 of Set 11 | vaitupu
# City not found. Skipping...
# Processing Record 18 of Set 11 | ambulu
# Processing Record 19 of Set 11 | vetralla
# Processing Record 20 of Set 11 | klamath falls
# Processing Record 21 of Set 11 | parrita
# Processing Record 22 of Set 11 | ampanihy
# Processing Record 23 of Set 11 | haines junction
# Processing Record 24 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 25 of Set 11 | hirara
# Processing Record 26 of Set 11 | trincomalee
# Processing Record 27 of Set 11 | progreso
# Processing Record 28 of Set 11 | pennagaram
# Processing Record 29 of Set 11 | louisbourg
# City not found. Skipping...
# Processing Record 30 of Set 11 | baiao
# Processing Record 31 of Set 11 | poum
# Processing Record 32 of Set 11 | rundu
# Processing Record 33 of Set 11 | moron
# Processing Record 34 of Set 11 | port hedland
# Processing Record 35 of Set 11 | vagur
# Processing Record 36 of Set 11 | aksu
# Processing Record 37 of Set 11 | balikpapan
# Processing Record 38 of Set 11 | peniche
# Processing Record 39 of Set 11 | nieuw nickerie
# Processing Record 40 of Set 11 | urumqi
# Processing Record 41 of Set 11 | panorama
# Processing Record 42 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 43 of Set 11 | madimba
# Processing Record 44 of Set 11 | katsuura
# Processing Record 45 of Set 11 | mrirt
# City not found. Skipping...
# Processing Record 46 of Set 11 | moree
# Processing Record 47 of Set 11 | san cristobal
# Processing Record 48 of Set 11 | lang son
# Processing Record 49 of Set 11 | uruacu
# Processing Record 50 of Set 11 | xining
# Processing Record 1 of Set 12 | primorsk
# Processing Record 2 of Set 12 | nome
# Processing Record 3 of Set 12 | nova vicosa
# Processing Record 4 of Set 12 | trapani
# Processing Record 5 of Set 12 | tilichiki
# Processing Record 6 of Set 12 | aras
# Processing Record 7 of Set 12 | ihosy
# Processing Record 8 of Set 12 | gari
# Processing Record 9 of Set 12 | gidam
# Processing Record 10 of Set 12 | fallon
# Processing Record 11 of Set 12 | monrovia
# Processing Record 12 of Set 12 | fougamou
# Processing Record 13 of Set 12 | darhan
# Processing Record 14 of Set 12 | pishin
# Processing Record 15 of Set 12 | nampa
# Processing Record 16 of Set 12 | sistranda
# Processing Record 17 of Set 12 | ambon
# Processing Record 18 of Set 12 | wanning
# Processing Record 19 of Set 12 | vershino-shakhtaminskiy
# Processing Record 20 of Set 12 | tocache
# Processing Record 21 of Set 12 | mayo
# Processing Record 22 of Set 12 | chegutu
# Processing Record 23 of Set 12 | machiques
# Processing Record 24 of Set 12 | taldan
# Processing Record 25 of Set 12 | guipavas
# Processing Record 26 of Set 12 | pacific grove
# Processing Record 27 of Set 12 | kaoma
# Processing Record 28 of Set 12 | nuuk
# Processing Record 29 of Set 12 | tocopilla
# Processing Record 30 of Set 12 | sabha
# Processing Record 31 of Set 12 | estacion coahuila
# Processing Record 32 of Set 12 | flin flon
# Processing Record 33 of Set 12 | goundam
# Processing Record 34 of Set 12 | key largo
# Processing Record 35 of Set 12 | the hammocks
# Processing Record 36 of Set 12 | kota belud
# Processing Record 37 of Set 12 | sinnamary
# Processing Record 38 of Set 12 | houma
# Processing Record 39 of Set 12 | gerardmer
# Processing Record 40 of Set 12 | erdenet
# Processing Record 41 of Set 12 | ulladulla
# Processing Record 42 of Set 12 | askiz
# Processing Record 43 of Set 12 | kollam
# Processing Record 44 of Set 12 | vidim
# Processing Record 45 of Set 12 | rorvik
# Processing Record 46 of Set 12 | albion
# Processing Record 47 of Set 12 | harderwijk
# Processing Record 48 of Set 12 | rameswaram
# Processing Record 49 of Set 12 | baherden
# Processing Record 50 of Set 12 | samarai
# Processing Record 1 of Set 13 | neuquen
# Processing Record 2 of Set 13 | markova
# Processing Record 3 of Set 13 | khovu-aksy
# Processing Record 4 of Set 13 | bor
# Processing Record 5 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 6 of Set 13 | mandalgovi
# Processing Record 7 of Set 13 | hobyo
# Processing Record 8 of Set 13 | roebourne
# Processing Record 9 of Set 13 | vanavara
# Processing Record 10 of Set 13 | shawnee
# Processing Record 11 of Set 13 | jacareacanga
# Processing Record 12 of Set 13 | shieli
# Processing Record 13 of Set 13 | chernyshevskiy
# Processing Record 14 of Set 13 | sola
# Processing Record 15 of Set 13 | komsomolskiy
# Processing Record 16 of Set 13 | oktyabrskoye
# Processing Record 17 of Set 13 | san vicente
# Processing Record 18 of Set 13 | casian
# Processing Record 19 of Set 13 | cabedelo
# Processing Record 20 of Set 13 | gizo
# Processing Record 21 of Set 13 | durania
# Processing Record 22 of Set 13 | dzhubga
# Processing Record 23 of Set 13 | nemuro
# Processing Record 24 of Set 13 | taoudenni
# Processing Record 25 of Set 13 | spornoye
# Processing Record 26 of Set 13 | kununurra
# Processing Record 27 of Set 13 | itagiba
# Processing Record 28 of Set 13 | erdaojiang
# Processing Record 29 of Set 13 | bokspits
# City not found. Skipping...
# Processing Record 30 of Set 13 | vadeni
# Processing Record 31 of Set 13 | lom sak
# Processing Record 32 of Set 13 | cervignano del friuli
# Processing Record 33 of Set 13 | goure
# Processing Record 34 of Set 13 | porto nacional
# Processing Record 35 of Set 13 | benguela
# Processing Record 36 of Set 13 | key west
# Processing Record 37 of Set 13 | kautokeino
# Processing Record 38 of Set 13 | springdale
# Processing Record 39 of Set 13 | cooma
# Processing Record 40 of Set 13 | nettuno
# Processing Record 41 of Set 13 | lusambo
# Processing Record 42 of Set 13 | cape canaveral
# Processing Record 43 of Set 13 | gat
# Processing Record 44 of Set 13 | santiago del estero
# Processing Record 45 of Set 13 | mukhen
# Processing Record 46 of Set 13 | omboue
# Processing Record 47 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 48 of Set 13 | port lincoln
# Processing Record 49 of Set 13 | lyubeshiv
# City not found. Skipping...
# Processing Record 50 of Set 13 | barauna
# Processing Record 1 of Set 14 | novikovo
# Processing Record 2 of Set 14 | vakhrushevo
# Processing Record 3 of Set 14 | cap malheureux
# Processing Record 4 of Set 14 | aripuana
# Processing Record 5 of Set 14 | tsentralnyy
# City not found. Skipping...
# Processing Record 6 of Set 14 | ukwa
# Processing Record 7 of Set 14 | ucluelet
# Processing Record 8 of Set 14 | puqi
# Processing Record 9 of Set 14 | rapid valley
# Processing Record 10 of Set 14 | sioux lookout
# Processing Record 11 of Set 14 | okahandja
# Processing Record 12 of Set 14 | drayton valley
# Processing Record 13 of Set 14 | zambezi
# Processing Record 14 of Set 14 | evinayong
# Processing Record 15 of Set 14 | bisho
# Processing Record 16 of Set 14 | camiri
# Processing Record 17 of Set 14 | ipanema
# Processing Record 18 of Set 14 | teya
# Processing Record 19 of Set 14 | viisoara
# Processing Record 20 of Set 14 | angoram
# Processing Record 21 of Set 14 | labytnangi
# Processing Record 22 of Set 14 | san pedro
# Processing Record 23 of Set 14 | nova gradiska
# Processing Record 24 of Set 14 | ust-kulom
# Processing Record 25 of Set 14 | chapais
# Processing Record 26 of Set 14 | nha trang
# Processing Record 27 of Set 14 | bunia
# Processing Record 28 of Set 14 | parksville
# Processing Record 29 of Set 14 | idah
# Processing Record 30 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 14 | navrongo
# Processing Record 32 of Set 14 | vesyegonsk
# Processing Record 33 of Set 14 | clyde river
# Processing Record 34 of Set 14 | palamos
# Processing Record 35 of Set 14 | san andres
# Processing Record 36 of Set 14 | zeya
# Processing Record 37 of Set 14 | barrhead
# Processing Record 38 of Set 14 | berdigestyakh
# Processing Record 39 of Set 14 | jackson
# Processing Record 40 of Set 14 | akyab
# Processing Record 41 of Set 14 | simga
# Processing Record 42 of Set 14 | calama
# Processing Record 43 of Set 14 | te anau
# Processing Record 44 of Set 14 | tevriz
# Processing Record 45 of Set 14 | turayf
# Processing Record 46 of Set 14 | saint-francois
# Processing Record 47 of Set 14 | lukavica
# Processing Record 48 of Set 14 | devils lake
# Processing Record 49 of Set 14 | banamba
# Processing Record 50 of Set 14 | honiara
# Processing Record 1 of Set 15 | barabinsk
# Processing Record 2 of Set 15 | debre tabor
# Processing Record 3 of Set 15 | ouegoa
# Processing Record 4 of Set 15 | stornoway
# Processing Record 5 of Set 15 | pathein
# Processing Record 6 of Set 15 | boende
# Processing Record 7 of Set 15 | lethem
# Processing Record 8 of Set 15 | haliyal
# Processing Record 9 of Set 15 | lodja
# Processing Record 10 of Set 15 | tsarychanka
# Processing Record 11 of Set 15 | laguna
# Processing Record 12 of Set 15 | molochnoye
# Processing Record 13 of Set 15 | labuhan
# Processing Record 14 of Set 15 | bhandaria
# Processing Record 15 of Set 15 | surgut
# Processing Record 16 of Set 15 | sukhumi
# Processing Record 17 of Set 15 | port keats
# Processing Record 18 of Set 15 | zhezkazgan
# Processing Record 19 of Set 15 | irbeyskoye
# Processing Record 20 of Set 15 | grand gaube
# Processing Record 21 of Set 15 | dancalan
# Processing Record 22 of Set 15 | mayen
# Processing Record 23 of Set 15 | dumas
# Processing Record 24 of Set 15 | krasnoturansk
# Processing Record 25 of Set 15 | wageningen
# Processing Record 26 of Set 15 | talaya
# Processing Record 27 of Set 15 | oriximina
# Processing Record 28 of Set 15 | patacamaya
# Processing Record 29 of Set 15 | khandyga
# Processing Record 30 of Set 15 | kokopo
# Processing Record 31 of Set 15 | gashua
# Processing Record 32 of Set 15 | shwebo
# Processing Record 33 of Set 15 | bubaque
# Processing Record 34 of Set 15 | ust-kut
# Processing Record 35 of Set 15 | andra
# Processing Record 36 of Set 15 | dicabisagan
# Processing Record 37 of Set 15 | banda aceh
# Processing Record 38 of Set 15 | bagru
# Processing Record 39 of Set 15 | sredniy ikorets
# Processing Record 40 of Set 15 | whitehorse
# Processing Record 41 of Set 15 | agadir
# Processing Record 42 of Set 15 | terney
# Processing Record 43 of Set 15 | punta alta
# Processing Record 44 of Set 15 | southbridge
# Processing Record 45 of Set 15 | cacoal
# Processing Record 46 of Set 15 | bam
# Processing Record 47 of Set 15 | kilmez
# City not found. Skipping...
# Processing Record 48 of Set 15 | alexandria
# Processing Record 49 of Set 15 | rabaul
# Processing Record 50 of Set 15 | nouadhibou
# Processing Record 1 of Set 16 | vangaindrano
# Processing Record 2 of Set 16 | pallisa
# Processing Record 3 of Set 16 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 16 | diapaga
# Processing Record 6 of Set 16 | ponta delgada
# Processing Record 7 of Set 16 | taltal
# Processing Record 8 of Set 16 | coahuayana
# Processing Record 9 of Set 16 | bicholim
# Processing Record 10 of Set 16 | kiama
# Processing Record 11 of Set 16 | seymchan
# Processing Record 12 of Set 16 | kwinana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a Pandas DataFrame 
city_database_df = pd.DataFrame(city_data)
city_database_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Tazovskiy  67.4667   78.7000     -1.07        83           5
# 1     Port Alfred -33.5906   26.8910     73.49        76           7
# 2          Atuona  -9.8000 -139.0333     77.05        81          16
# 3          Lodwar   3.1191   35.5973     93.04        20          31
# 4       Ugoofaaru   5.6667   73.0000     81.50        74          85
# 5       Busselton -33.6500  115.3333     72.09        77           5
# 6      Correntina -13.3433  -44.6367     82.51        64         100
# 7         Ushuaia -54.8000  -68.3000     49.62        81          75
# 8          Albany  42.6001  -73.9662     43.52        82          96
# 9  Saint-Philippe -21.3585   55.7679     78.39        79          23
#
#    Wind Speed Weather Description
# 0       15.57           clear sky
# 1       14.81           clear sky
# 2       15.88          light rain
# 3        9.33    scattered clouds
# 4       13.49     overcast clouds
# 5        9.44           clear sky
# 6        2.95     overcast clouds
# 7       31.07             drizzle
# 8        1.01     overcast clouds
# 9        6.67          few clouds

# %%
# Create the output file, CSV
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the city data into a CSV
city_database_df.to_csv(output_data_file, index_label = "City_ID")

# %%
# import the dependencies
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(-90.000,90.000,size=2000)
lngs = np.random.uniform(-180.000,180.000,size=2000)
lat_lngs = zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes into a list 
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Create a list for holding the cities 
cities = []
# Identify the nearest city for each longitude and latitude combination
for coordinate in coordinates: 
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list
    if city not in cities: 
        cities.append(city)
# print the city length to confirm sufficient count
len(cities)
# Out:
# 735

# %%
# Import the requests library
import requests
# import the API key
from config import weather_api_key

# %%
import time

# %%
# Create a base url
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data 
city_data = []
# Print the beginning of the logging 
print("Beginning Data Retrieval   ")
print("---------------------------")

# create counters 
record_count = 1
set_count = 1

# Loop through all of the cities in our list 
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes 
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL for each city 
    city_url = url + "&q=" + city.replace(" ", "+")

     # Log the URL, record, and set numbers and the city
    print(f'Processing Record {record_count} of Set {set_count} | {city}')

    # Add 1 to the record count 
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": weather_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------
# Processing Record 1 of Set 1 | santa maria
# Processing Record 2 of Set 1 | tasiilaq
# Processing Record 3 of Set 1 | puerto ayora
# Processing Record 4 of Set 1 | grindavik
# Processing Record 5 of Set 1 | iqaluit
# Processing Record 6 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | sao joao da barra
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | dunedin
# Processing Record 11 of Set 1 | mataura
# Processing Record 12 of Set 1 | kirakira
# Processing Record 13 of Set 1 | san juan
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | pensacola
# Processing Record 16 of Set 1 | sambava
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | saint-pierre
# Processing Record 20 of Set 1 | rosarito
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 24 of Set 1 | mar del plata
# Processing Record 25 of Set 1 | castro
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | hermanus
# Processing Record 28 of Set 1 | barrow
# Processing Record 29 of Set 1 | georgetown
# Processing Record 30 of Set 1 | hobart
# Processing Record 31 of Set 1 | bambous virieux
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | dikson
# Processing Record 34 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 1 | gat
# Processing Record 36 of Set 1 | minggang
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | manokwari
# Processing Record 39 of Set 1 | port alfred
# Processing Record 40 of Set 1 | ribeira grande
# Processing Record 41 of Set 1 | cidreira
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | mokrous
# Processing Record 45 of Set 1 | san cristobal
# Processing Record 46 of Set 1 | san policarpo
# Processing Record 47 of Set 1 | aswan
# Processing Record 48 of Set 1 | butaritari
# Processing Record 49 of Set 1 | hamilton
# Processing Record 50 of Set 1 | jamestown
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | moindou
# Processing Record 3 of Set 2 | pisco
# Processing Record 4 of Set 2 | berlevag
# Processing Record 5 of Set 2 | vaini
# Processing Record 6 of Set 2 | kathmandu
# Processing Record 7 of Set 2 | alofi
# Processing Record 8 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 9 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 2 | sayat
# Processing Record 11 of Set 2 | pandan
# Processing Record 12 of Set 2 | nikolskoye
# Processing Record 13 of Set 2 | aklavik
# Processing Record 14 of Set 2 | neuquen
# Processing Record 15 of Set 2 | mount isa
# Processing Record 16 of Set 2 | kahului
# Processing Record 17 of Set 2 | tuatapere
# Processing Record 18 of Set 2 | bredasdorp
# Processing Record 19 of Set 2 | macara
# Processing Record 20 of Set 2 | peleduy
# Processing Record 21 of Set 2 | laguna
# Processing Record 22 of Set 2 | lasa
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | lavrentiya
# Processing Record 25 of Set 2 | bethel
# Processing Record 26 of Set 2 | hilo
# Processing Record 27 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 28 of Set 2 | havre-saint-pierre
# Processing Record 29 of Set 2 | saint-philippe
# Processing Record 30 of Set 2 | nabire
# Processing Record 31 of Set 2 | yirol
# City not found. Skipping...
# Processing Record 32 of Set 2 | kamaishi
# Processing Record 33 of Set 2 | pacific grove
# Processing Record 34 of Set 2 | muros
# Processing Record 35 of Set 2 | ozgon
# City not found. Skipping...
# Processing Record 36 of Set 2 | port hardy
# Processing Record 37 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 2 | matadi
# Processing Record 39 of Set 2 | tias
# Processing Record 40 of Set 2 | minna
# Processing Record 41 of Set 2 | portage
# Processing Record 42 of Set 2 | aksarka
# Processing Record 43 of Set 2 | carnarvon
# Processing Record 44 of Set 2 | cape town
# Processing Record 45 of Set 2 | kulhudhuffushi
# Processing Record 46 of Set 2 | kontagora
# Processing Record 47 of Set 2 | kingston
# Processing Record 48 of Set 2 | arraial do cabo
# Processing Record 49 of Set 2 | natal
# Processing Record 50 of Set 2 | bulach
# Processing Record 1 of Set 3 | walvis bay
# Processing Record 2 of Set 3 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 3 | lorengau
# Processing Record 4 of Set 3 | ambanja
# Processing Record 5 of Set 3 | provideniya
# Processing Record 6 of Set 3 | touros
# Processing Record 7 of Set 3 | atuona
# Processing Record 8 of Set 3 | teya
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 11 of Set 3 | qaanaaq
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | saldanha
# Processing Record 14 of Set 3 | mahebourg
# Processing Record 15 of Set 3 | russkaya polyana
# Processing Record 16 of Set 3 | egvekinot
# Processing Record 17 of Set 3 | avarua
# Processing Record 18 of Set 3 | coahuayana
# Processing Record 19 of Set 3 | felanitx
# Processing Record 20 of Set 3 | faanui
# Processing Record 21 of Set 3 | bowen
# Processing Record 22 of Set 3 | bago
# Processing Record 23 of Set 3 | husavik
# Processing Record 24 of Set 3 | airai
# Processing Record 25 of Set 3 | lagoa
# Processing Record 26 of Set 3 | veraval
# Processing Record 27 of Set 3 | launceston
# Processing Record 28 of Set 3 | xuchang
# Processing Record 29 of Set 3 | buraydah
# Processing Record 30 of Set 3 | bolshaya izhora
# Processing Record 31 of Set 3 | mandalgovi
# Processing Record 32 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 3 | cody
# Processing Record 34 of Set 3 | alice springs
# Processing Record 35 of Set 3 | thompson
# Processing Record 36 of Set 3 | cravo norte
# Processing Record 37 of Set 3 | adre
# Processing Record 38 of Set 3 | iquique
# Processing Record 39 of Set 3 | yugorsk
# Processing Record 40 of Set 3 | vardo
# Processing Record 41 of Set 3 | port hedland
# Processing Record 42 of Set 3 | komsomolskiy
# Processing Record 43 of Set 3 | bousso
# Processing Record 44 of Set 3 | zolotinka
# City not found. Skipping...
# Processing Record 45 of Set 3 | port lincoln
# Processing Record 46 of Set 3 | pevek
# Processing Record 47 of Set 3 | bilibino
# Processing Record 48 of Set 3 | gornopravdinsk
# Processing Record 49 of Set 3 | buchanan
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 4 | la ronge
# Processing Record 3 of Set 4 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 4 | hengyang
# Processing Record 5 of Set 4 | hasaki
# Processing Record 6 of Set 4 | scottsbluff
# Processing Record 7 of Set 4 | ugoofaaru
# Processing Record 8 of Set 4 | victoria
# Processing Record 9 of Set 4 | malaya purga
# Processing Record 10 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 4 | garm
# City not found. Skipping...
# Processing Record 12 of Set 4 | hambantota
# Processing Record 13 of Set 4 | chokurdakh
# Processing Record 14 of Set 4 | narsaq
# Processing Record 15 of Set 4 | masterton
# Processing Record 16 of Set 4 | oranjemund
# Processing Record 17 of Set 4 | ahipara
# Processing Record 18 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 19 of Set 4 | palmer
# Processing Record 20 of Set 4 | atar
# Processing Record 21 of Set 4 | carauari
# Processing Record 22 of Set 4 | gondar
# Processing Record 23 of Set 4 | erzin
# Processing Record 24 of Set 4 | port elizabeth
# Processing Record 25 of Set 4 | vammala
# Processing Record 26 of Set 4 | bathsheba
# Processing Record 27 of Set 4 | asau
# Processing Record 28 of Set 4 | kungurtug
# Processing Record 29 of Set 4 | cabo san lucas
# Processing Record 30 of Set 4 | xichang
# Processing Record 31 of Set 4 | cururupu
# Processing Record 32 of Set 4 | tiksi
# Processing Record 33 of Set 4 | valparaiso
# Processing Record 34 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 35 of Set 4 | rosetta
# Processing Record 36 of Set 4 | itoman
# Processing Record 37 of Set 4 | phan rang
# City not found. Skipping...
# Processing Record 38 of Set 4 | brownsville
# Processing Record 39 of Set 4 | portoferraio
# Processing Record 40 of Set 4 | ippy
# Processing Record 41 of Set 4 | darnah
# Processing Record 42 of Set 4 | severo-kurilsk
# Processing Record 43 of Set 4 | san patricio
# Processing Record 44 of Set 4 | ostrovnoy
# Processing Record 45 of Set 4 | east wenatchee bench
# Processing Record 46 of Set 4 | myre
# Processing Record 47 of Set 4 | armacao dos buzios
# City not found. Skipping...
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 50 of Set 4 | eenhana
# Processing Record 1 of Set 5 | kuandian
# Processing Record 2 of Set 5 | ancud
# Processing Record 3 of Set 5 | san jeronimo
# Processing Record 4 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 5 of Set 5 | ocampo
# Processing Record 6 of Set 5 | vila do maio
# Processing Record 7 of Set 5 | khatanga
# Processing Record 8 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 9 of Set 5 | kununurra
# Processing Record 10 of Set 5 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 5 | mata
# Processing Record 12 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 5 | bahia blanca
# Processing Record 14 of Set 5 | digby
# Processing Record 15 of Set 5 | haines junction
# Processing Record 16 of Set 5 | hvide sande
# Processing Record 17 of Set 5 | derzhavinsk
# Processing Record 18 of Set 5 | tacuati
# Processing Record 19 of Set 5 | fremont
# Processing Record 20 of Set 5 | sinop
# Processing Record 21 of Set 5 | upernavik
# Processing Record 22 of Set 5 | hokitika
# Processing Record 23 of Set 5 | henzada
# City not found. Skipping...
# Processing Record 24 of Set 5 | skalistyy
# City not found. Skipping...
# Processing Record 25 of Set 5 | elko
# Processing Record 26 of Set 5 | qandala
# Processing Record 27 of Set 5 | ixtapa
# Processing Record 28 of Set 5 | saint-augustin
# Processing Record 29 of Set 5 | taltal
# Processing Record 30 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 31 of Set 5 | tomatlan
# Processing Record 32 of Set 5 | jardim
# Processing Record 33 of Set 5 | coihaique
# Processing Record 34 of Set 5 | ambilobe
# Processing Record 35 of Set 5 | kang
# Processing Record 36 of Set 5 | aksaray
# Processing Record 37 of Set 5 | noumea
# Processing Record 38 of Set 5 | moose factory
# Processing Record 39 of Set 5 | sibolga
# Processing Record 40 of Set 5 | udachnyy
# Processing Record 41 of Set 5 | new norfolk
# Processing Record 42 of Set 5 | hithadhoo
# Processing Record 43 of Set 5 | poum
# Processing Record 44 of Set 5 | stromness
# Processing Record 45 of Set 5 | madang
# Processing Record 46 of Set 5 | brae
# Processing Record 47 of Set 5 | saint george
# Processing Record 48 of Set 5 | mocoa
# Processing Record 49 of Set 5 | lensk
# Processing Record 50 of Set 5 | abu dhabi
# Processing Record 1 of Set 6 | sorland
# Processing Record 2 of Set 6 | mufumbwe
# Processing Record 3 of Set 6 | baruun-urt
# Processing Record 4 of Set 6 | thinadhoo
# Processing Record 5 of Set 6 | sembe
# Processing Record 6 of Set 6 | pangai
# Processing Record 7 of Set 6 | jingdezhen
# Processing Record 8 of Set 6 | kwinana
# Processing Record 9 of Set 6 | tocopilla
# Processing Record 10 of Set 6 | athabasca
# Processing Record 11 of Set 6 | old town
# Processing Record 12 of Set 6 | vestmanna
# Processing Record 13 of Set 6 | kavaratti
# Processing Record 14 of Set 6 | makat
# Processing Record 15 of Set 6 | pauini
# Processing Record 16 of Set 6 | faya
# Processing Record 17 of Set 6 | dalvik
# Processing Record 18 of Set 6 | hatillo
# Processing Record 19 of Set 6 | pangnirtung
# Processing Record 20 of Set 6 | yamaranguila
# Processing Record 21 of Set 6 | katsuura
# Processing Record 22 of Set 6 | tuggurt
# City not found. Skipping...
# Processing Record 23 of Set 6 | camacha
# Processing Record 24 of Set 6 | umea
# Processing Record 25 of Set 6 | beringovskiy
# Processing Record 26 of Set 6 | adwa
# Processing Record 27 of Set 6 | tessalit
# Processing Record 28 of Set 6 | longlac
# City not found. Skipping...
# Processing Record 29 of Set 6 | mpongwe
# Processing Record 30 of Set 6 | rawson
# Processing Record 31 of Set 6 | fortuna
# Processing Record 32 of Set 6 | santa isabel do rio negro
# Processing Record 33 of Set 6 | praia
# Processing Record 34 of Set 6 | segou
# Processing Record 35 of Set 6 | luchegorsk
# Processing Record 36 of Set 6 | slave lake
# Processing Record 37 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 38 of Set 6 | port blair
# Processing Record 39 of Set 6 | micheldorf
# Processing Record 40 of Set 6 | nadvoitsy
# Processing Record 41 of Set 6 | salalah
# Processing Record 42 of Set 6 | saskylakh
# Processing Record 43 of Set 6 | sitka
# Processing Record 44 of Set 6 | ewa beach
# Processing Record 45 of Set 6 | namatanai
# Processing Record 46 of Set 6 | maragogi
# Processing Record 47 of Set 6 | nolinsk
# Processing Record 48 of Set 6 | yangjiang
# Processing Record 49 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 50 of Set 6 | kangaatsiaq
# Processing Record 1 of Set 7 | saint-paul
# Processing Record 2 of Set 7 | kapoeta
# Processing Record 3 of Set 7 | kondinskoye
# Processing Record 4 of Set 7 | chapais
# Processing Record 5 of Set 7 | yulara
# Processing Record 6 of Set 7 | sisimiut
# Processing Record 7 of Set 7 | mazamari
# Processing Record 8 of Set 7 | afmadu
# City not found. Skipping...
# Processing Record 9 of Set 7 | aketi
# Processing Record 10 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 11 of Set 7 | hailar
# Processing Record 12 of Set 7 | hami
# Processing Record 13 of Set 7 | biak
# Processing Record 14 of Set 7 | kruisfontein
# Processing Record 15 of Set 7 | klaksvik
# Processing Record 16 of Set 7 | irbeyskoye
# Processing Record 17 of Set 7 | kirkwall
# Processing Record 18 of Set 7 | dingle
# Processing Record 19 of Set 7 | nargana
# Processing Record 20 of Set 7 | jumla
# Processing Record 21 of Set 7 | avera
# Processing Record 22 of Set 7 | carbonia
# Processing Record 23 of Set 7 | zhigansk
# Processing Record 24 of Set 7 | margate
# Processing Record 25 of Set 7 | sibu
# Processing Record 26 of Set 7 | mbandaka
# Processing Record 27 of Set 7 | loanda
# Processing Record 28 of Set 7 | marawi
# Processing Record 29 of Set 7 | panguna
# Processing Record 30 of Set 7 | kamenka
# Processing Record 31 of Set 7 | owasso
# Processing Record 32 of Set 7 | vanimo
# Processing Record 33 of Set 7 | kapit
# Processing Record 34 of Set 7 | calabozo
# Processing Record 35 of Set 7 | mendoza
# Processing Record 36 of Set 7 | amapa
# Processing Record 37 of Set 7 | talnakh
# Processing Record 38 of Set 7 | fukue
# Processing Record 39 of Set 7 | oriximina
# Processing Record 40 of Set 7 | alagoinhas
# Processing Record 41 of Set 7 | bentiu
# Processing Record 42 of Set 7 | chara
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | tukrah
# Processing Record 45 of Set 7 | amga
# Processing Record 46 of Set 7 | kodiak
# Processing Record 47 of Set 7 | mandera
# Processing Record 48 of Set 7 | chaumont
# Processing Record 49 of Set 7 | luderitz
# Processing Record 50 of Set 7 | neepawa
# Processing Record 1 of Set 8 | bafq
# Processing Record 2 of Set 8 | norman wells
# Processing Record 3 of Set 8 | batagay
# Processing Record 4 of Set 8 | ust-kuyga
# Processing Record 5 of Set 8 | hay river
# Processing Record 6 of Set 8 | zlatoustovsk
# City not found. Skipping...
# Processing Record 7 of Set 8 | hoa binh
# Processing Record 8 of Set 8 | guisa
# Processing Record 9 of Set 8 | mackenzie
# Processing Record 10 of Set 8 | lang son
# Processing Record 11 of Set 8 | labuhan
# Processing Record 12 of Set 8 | barawe
# City not found. Skipping...
# Processing Record 13 of Set 8 | souillac
# Processing Record 14 of Set 8 | sayyan
# Processing Record 15 of Set 8 | cayenne
# Processing Record 16 of Set 8 | jiwani
# Processing Record 17 of Set 8 | belmonte
# Processing Record 18 of Set 8 | freeport
# Processing Record 19 of Set 8 | pacifica
# Processing Record 20 of Set 8 | coos bay
# Processing Record 21 of Set 8 | clyde river
# Processing Record 22 of Set 8 | itarema
# Processing Record 23 of Set 8 | trelew
# Processing Record 24 of Set 8 | geraldton
# Processing Record 25 of Set 8 | garoua
# Processing Record 26 of Set 8 | umtata
# Processing Record 27 of Set 8 | monchegorsk
# Processing Record 28 of Set 8 | ihosy
# Processing Record 29 of Set 8 | orange
# Processing Record 30 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 31 of Set 8 | champerico
# Processing Record 32 of Set 8 | chernyshevskiy
# Processing Record 33 of Set 8 | meulaboh
# Processing Record 34 of Set 8 | kracheh
# City not found. Skipping...
# Processing Record 35 of Set 8 | chulman
# Processing Record 36 of Set 8 | goderich
# Processing Record 37 of Set 8 | verkhoyansk
# Processing Record 38 of Set 8 | gutierrez zamora
# Processing Record 39 of Set 8 | setermoen
# Processing Record 40 of Set 8 | nacogdoches
# Processing Record 41 of Set 8 | portland
# Processing Record 42 of Set 8 | raton
# Processing Record 43 of Set 8 | niamey
# Processing Record 44 of Set 8 | balkanabat
# Processing Record 45 of Set 8 | talcahuano
# Processing Record 46 of Set 8 | goreloye
# Processing Record 47 of Set 8 | santa isabel
# Processing Record 48 of Set 8 | enid
# Processing Record 49 of Set 8 | gangawati
# Processing Record 50 of Set 8 | galle
# Processing Record 1 of Set 9 | illapel
# Processing Record 2 of Set 9 | suleja
# Processing Record 3 of Set 9 | inhambane
# Processing Record 4 of Set 9 | beloha
# Processing Record 5 of Set 9 | lithakia
# Processing Record 6 of Set 9 | the valley
# Processing Record 7 of Set 9 | lazaro cardenas
# Processing Record 8 of Set 9 | ngunguru
# Processing Record 9 of Set 9 | sobolevo
# Processing Record 10 of Set 9 | anadyr
# Processing Record 11 of Set 9 | general roca
# Processing Record 12 of Set 9 | carutapera
# Processing Record 13 of Set 9 | hovd
# Processing Record 14 of Set 9 | eskasem
# City not found. Skipping...
# Processing Record 15 of Set 9 | coquimbo
# Processing Record 16 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 9 | vysokogornyy
# Processing Record 18 of Set 9 | acapulco
# Processing Record 19 of Set 9 | brokopondo
# Processing Record 20 of Set 9 | altoona
# Processing Record 21 of Set 9 | colonial heights
# Processing Record 22 of Set 9 | batemans bay
# Processing Record 23 of Set 9 | waddan
# Processing Record 24 of Set 9 | puerto escondido
# Processing Record 25 of Set 9 | coihueco
# Processing Record 26 of Set 9 | boundiali
# Processing Record 27 of Set 9 | nantucket
# Processing Record 28 of Set 9 | surgut
# Processing Record 29 of Set 9 | gwadar
# Processing Record 30 of Set 9 | batesville
# Processing Record 31 of Set 9 | caravelas
# Processing Record 32 of Set 9 | half moon bay
# Processing Record 33 of Set 9 | buala
# Processing Record 34 of Set 9 | blagoyevo
# Processing Record 35 of Set 9 | angoche
# Processing Record 36 of Set 9 | nizhniy ingash
# Processing Record 37 of Set 9 | tanete
# Processing Record 38 of Set 9 | nioro
# Processing Record 39 of Set 9 | marsa matruh
# Processing Record 40 of Set 9 | mahaicony
# City not found. Skipping...
# Processing Record 41 of Set 9 | sandnessjoen
# Processing Record 42 of Set 9 | abomsa
# Processing Record 43 of Set 9 | quatre cocos
# Processing Record 44 of Set 9 | svetlyy
# Processing Record 45 of Set 9 | nagato
# Processing Record 46 of Set 9 | imbituba
# Processing Record 47 of Set 9 | tubuala
# Processing Record 48 of Set 9 | ilhabela
# Processing Record 49 of Set 9 | saurimo
# Processing Record 50 of Set 9 | gizo
# Processing Record 1 of Set 10 | porto nacional
# Processing Record 2 of Set 10 | kawalu
# Processing Record 3 of Set 10 | te anau
# Processing Record 4 of Set 10 | acari
# Processing Record 5 of Set 10 | maniitsoq
# Processing Record 6 of Set 10 | nome
# Processing Record 7 of Set 10 | berdigestyakh
# Processing Record 8 of Set 10 | tura
# Processing Record 9 of Set 10 | kenora
# Processing Record 10 of Set 10 | yanan
# City not found. Skipping...
# Processing Record 11 of Set 10 | aykhal
# Processing Record 12 of Set 10 | cockburn town
# Processing Record 13 of Set 10 | rio grande
# Processing Record 14 of Set 10 | bonfim
# Processing Record 15 of Set 10 | celestun
# Processing Record 16 of Set 10 | smithers
# Processing Record 17 of Set 10 | longyearbyen
# Processing Record 18 of Set 10 | varkaus
# Processing Record 19 of Set 10 | campoverde
# Processing Record 20 of Set 10 | shingu
# Processing Record 21 of Set 10 | nampula
# Processing Record 22 of Set 10 | dabakala
# Processing Record 23 of Set 10 | chuy
# Processing Record 24 of Set 10 | isangel
# Processing Record 25 of Set 10 | ponta do sol
# Processing Record 26 of Set 10 | kilindoni
# Processing Record 27 of Set 10 | viedma
# Processing Record 28 of Set 10 | namibe
# Processing Record 29 of Set 10 | flinders
# Processing Record 30 of Set 10 | antofagasta
# Processing Record 31 of Set 10 | santa barbara
# Processing Record 32 of Set 10 | ignalina
# Processing Record 33 of Set 10 | pato-o
# Processing Record 34 of Set 10 | necochea
# Processing Record 35 of Set 10 | borogontsy
# Processing Record 36 of Set 10 | tambopata
# Processing Record 37 of Set 10 | codrington
# Processing Record 38 of Set 10 | bambanglipuro
# Processing Record 39 of Set 10 | bereda
# Processing Record 40 of Set 10 | lakes entrance
# Processing Record 41 of Set 10 | isiro
# Processing Record 42 of Set 10 | tabou
# Processing Record 43 of Set 10 | atocha
# Processing Record 44 of Set 10 | roald
# Processing Record 45 of Set 10 | belyy yar
# Processing Record 46 of Set 10 | samalaeulu
# City not found. Skipping...
# Processing Record 47 of Set 10 | edmonton
# Processing Record 48 of Set 10 | calamar
# Processing Record 49 of Set 10 | samaipata
# Processing Record 50 of Set 10 | nishihara
# Processing Record 1 of Set 11 | dhidhdhoo
# Processing Record 2 of Set 11 | baglan
# Processing Record 3 of Set 11 | oussouye
# Processing Record 4 of Set 11 | linjiang
# Processing Record 5 of Set 11 | presidencia roque saenz pena
# Processing Record 6 of Set 11 | sorvag
# City not found. Skipping...
# Processing Record 7 of Set 11 | dong hoi
# Processing Record 8 of Set 11 | davenda
# Processing Record 9 of Set 11 | san miguel
# Processing Record 10 of Set 11 | yar-sale
# Processing Record 11 of Set 11 | aquiraz
# Processing Record 12 of Set 11 | vostok
# Processing Record 13 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 11 | tsabong
# Processing Record 15 of Set 11 | tooele
# Processing Record 16 of Set 11 | grand gaube
# Processing Record 17 of Set 11 | ishigaki
# Processing Record 18 of Set 11 | inuvik
# Processing Record 19 of Set 11 | grand centre
# City not found. Skipping...
# Processing Record 20 of Set 11 | kautokeino
# Processing Record 21 of Set 11 | yatou
# Processing Record 22 of Set 11 | naze
# Processing Record 23 of Set 11 | muravlenko
# Processing Record 24 of Set 11 | dahuk
# Processing Record 25 of Set 11 | vila franca do campo
# Processing Record 26 of Set 11 | bandipur
# Processing Record 27 of Set 11 | iralaya
# Processing Record 28 of Set 11 | west fargo
# Processing Record 29 of Set 11 | mocuba
# Processing Record 30 of Set 11 | nemuro
# Processing Record 31 of Set 11 | tutoia
# Processing Record 32 of Set 11 | toamasina
# Processing Record 33 of Set 11 | karavayevo
# Processing Record 34 of Set 11 | lesosibirsk
# Processing Record 35 of Set 11 | merauke
# Processing Record 36 of Set 11 | lipnita
# Processing Record 37 of Set 11 | dickson
# Processing Record 38 of Set 11 | karratha
# Processing Record 39 of Set 11 | purpe
# Processing Record 40 of Set 11 | zeya
# Processing Record 41 of Set 11 | vila velha
# Processing Record 42 of Set 11 | outjo
# Processing Record 43 of Set 11 | eureka
# Processing Record 44 of Set 11 | elkhart
# Processing Record 45 of Set 11 | pijijiapan
# Processing Record 46 of Set 11 | yaan
# Processing Record 47 of Set 11 | bengkulu
# Processing Record 48 of Set 11 | punta alta
# Processing Record 49 of Set 11 | eyl
# Processing Record 50 of Set 11 | vestmannaeyjar
# Processing Record 1 of Set 12 | andra
# Processing Record 2 of Set 12 | nanortalik
# Processing Record 3 of Set 12 | broome
# Processing Record 4 of Set 12 | ulaangom
# Processing Record 5 of Set 12 | lompoc
# Processing Record 6 of Set 12 | beyneu
# Processing Record 7 of Set 12 | nichinan
# Processing Record 8 of Set 12 | ibirite
# Processing Record 9 of Set 12 | pokhara
# Processing Record 10 of Set 12 | san pedro
# Processing Record 11 of Set 12 | barabai
# Processing Record 12 of Set 12 | gama
# Processing Record 13 of Set 12 | balud
# Processing Record 14 of Set 12 | mingyue
# Processing Record 15 of Set 12 | kamen-rybolov
# Processing Record 16 of Set 12 | gisborne
# Processing Record 17 of Set 12 | aripuana
# Processing Record 18 of Set 12 | ambovombe
# Processing Record 19 of Set 12 | rezekne
# Processing Record 20 of Set 12 | maldonado
# Processing Record 21 of Set 12 | panjab
# Processing Record 22 of Set 12 | ozinki
# Processing Record 23 of Set 12 | zatoka
# Processing Record 24 of Set 12 | prince rupert
# Processing Record 25 of Set 12 | trapani
# Processing Record 26 of Set 12 | ihlow
# Processing Record 27 of Set 12 | tarbes
# Processing Record 28 of Set 12 | constantine
# Processing Record 29 of Set 12 | sao filipe
# Processing Record 30 of Set 12 | vangaindrano
# Processing Record 31 of Set 12 | lubango
# Processing Record 32 of Set 12 | bloemfontein
# Processing Record 33 of Set 12 | wabrzezno
# Processing Record 34 of Set 12 | inderborskiy
# City not found. Skipping...
# Processing Record 35 of Set 12 | debre tabor
# Processing Record 36 of Set 12 | teahupoo
# Processing Record 37 of Set 12 | salou
# Processing Record 38 of Set 12 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 12 | curaca
# Processing Record 40 of Set 12 | ribas do rio pardo
# Processing Record 41 of Set 12 | baykit
# Processing Record 42 of Set 12 | kalmunai
# Processing Record 43 of Set 12 | nicoya
# Processing Record 44 of Set 12 | maceio
# Processing Record 45 of Set 12 | ust-ilimsk
# Processing Record 46 of Set 12 | troitsk
# Processing Record 47 of Set 12 | ilulissat
# Processing Record 48 of Set 12 | omboue
# Processing Record 49 of Set 12 | tazmalt
# Processing Record 50 of Set 12 | ankang
# Processing Record 1 of Set 13 | tubruq
# City not found. Skipping...
# Processing Record 2 of Set 13 | paamiut
# Processing Record 3 of Set 13 | kurumkan
# Processing Record 4 of Set 13 | samarai
# Processing Record 5 of Set 13 | kristiansund
# Processing Record 6 of Set 13 | qesarya
# Processing Record 7 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 8 of Set 13 | lewiston
# Processing Record 9 of Set 13 | tual
# Processing Record 10 of Set 13 | bloomingdale
# Processing Record 11 of Set 13 | matara
# Processing Record 12 of Set 13 | eidsvag
# Processing Record 13 of Set 13 | jesup
# Processing Record 14 of Set 13 | khorramshahr
# Processing Record 15 of Set 13 | tommot
# Processing Record 16 of Set 13 | karaton
# Processing Record 17 of Set 13 | northam
# Processing Record 18 of Set 13 | marzuq
# Processing Record 19 of Set 13 | bonavista
# Processing Record 20 of Set 13 | ossett
# Processing Record 21 of Set 13 | beidao
# Processing Record 22 of Set 13 | auki
# Processing Record 23 of Set 13 | seoul
# Processing Record 24 of Set 13 | diego de almagro
# Processing Record 25 of Set 13 | soyo
# Processing Record 26 of Set 13 | mobaye
# Processing Record 27 of Set 13 | puerto cabezas
# Processing Record 28 of Set 13 | vallenar
# Processing Record 29 of Set 13 | agua verde
# Processing Record 30 of Set 13 | louth
# Processing Record 31 of Set 13 | truth or consequences
# Processing Record 32 of Set 13 | stornoway
# Processing Record 33 of Set 13 | adrar
# Processing Record 34 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 35 of Set 13 | olafsvik
# Processing Record 36 of Set 13 | moerai
# Processing Record 37 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 38 of Set 13 | palmerston
# Processing Record 39 of Set 13 | krasavino
# Processing Record 40 of Set 13 | hirara
# Processing Record 41 of Set 13 | arman
# Processing Record 42 of Set 13 | yokadouma
# Processing Record 43 of Set 13 | tezu
# Processing Record 44 of Set 13 | nombre de dios
# Processing Record 45 of Set 13 | batticaloa
# Processing Record 46 of Set 13 | kenai
# Processing Record 47 of Set 13 | batagay-alyta
# Processing Record 48 of Set 13 | emet
# Processing Record 49 of Set 13 | pio ix
# Processing Record 50 of Set 13 | linfen
# Processing Record 1 of Set 14 | mogadishu
# Processing Record 2 of Set 14 | mayo
# Processing Record 3 of Set 14 | ende
# Processing Record 4 of Set 14 | ukiah
# Processing Record 5 of Set 14 | coulihaut
# City not found. Skipping...
# Processing Record 6 of Set 14 | otjimbingwe
# Processing Record 7 of Set 14 | woodward
# Processing Record 8 of Set 14 | singaparna
# Processing Record 9 of Set 14 | vao
# Processing Record 10 of Set 14 | adelaide
# Processing Record 11 of Set 14 | resistencia
# Processing Record 12 of Set 14 | mollendo
# Processing Record 13 of Set 14 | kailua
# Processing Record 14 of Set 14 | progreso
# Processing Record 15 of Set 14 | kyshtovka
# Processing Record 16 of Set 14 | san andres
# Processing Record 17 of Set 14 | zhob
# Processing Record 18 of Set 14 | ormara
# Processing Record 19 of Set 14 | leningradskiy
# Processing Record 20 of Set 14 | evensk
# Processing Record 21 of Set 14 | charters towers
# Processing Record 22 of Set 14 | picota
# Processing Record 23 of Set 14 | bitung
# Processing Record 24 of Set 14 | kachikau
# City not found. Skipping...
# Processing Record 25 of Set 14 | abalak
# Processing Record 26 of Set 14 | rudnichnyy
# Processing Record 27 of Set 14 | santa cruz
# Processing Record 28 of Set 14 | bryan
# Processing Record 29 of Set 14 | sabla
# Processing Record 30 of Set 14 | moussoro
# Processing Record 31 of Set 14 | comodoro rivadavia
# Processing Record 32 of Set 14 | laurel
# Processing Record 33 of Set 14 | new port richey
# Processing Record 34 of Set 14 | toba tek singh
# Processing Record 35 of Set 14 | kabanga
# Processing Record 36 of Set 14 | wuan
# Processing Record 37 of Set 14 | malwan
# City not found. Skipping...
# Processing Record 38 of Set 14 | marquette
# Processing Record 39 of Set 14 | uzhur
# Processing Record 40 of Set 14 | samfya
# Processing Record 41 of Set 14 | liyang
# Processing Record 42 of Set 14 | subate
# Processing Record 43 of Set 14 | hofn
# Processing Record 44 of Set 14 | filadelfia
# Processing Record 45 of Set 14 | sidmouth
# Processing Record 46 of Set 14 | dullewala
# Processing Record 47 of Set 14 | nairobi
# Processing Record 48 of Set 14 | young
# Processing Record 49 of Set 14 | hesla
# Processing Record 50 of Set 14 | xining
# Processing Record 1 of Set 15 | pouembout
# Processing Record 2 of Set 15 | columbus
# Processing Record 3 of Set 15 | balabac
# Processing Record 4 of Set 15 | wanaka
# Processing Record 5 of Set 15 | jacareacanga
# Processing Record 6 of Set 15 | mahajanga
# Processing Record 7 of Set 15 | road town
# Processing Record 8 of Set 15 | bar harbor
# Processing Record 9 of Set 15 | hudson bay
# Processing Record 10 of Set 15 | luganville
# Processing Record 11 of Set 15 | kamyaran
# Processing Record 12 of Set 15 | kathu
# Processing Record 13 of Set 15 | am timan
# Processing Record 14 of Set 15 | salinopolis
# Processing Record 15 of Set 15 | upington
# Processing Record 16 of Set 15 | alta floresta
# Processing Record 17 of Set 15 | krasnogorsk
# Processing Record 18 of Set 15 | ouagadougou
# Processing Record 19 of Set 15 | kitangari
# Processing Record 20 of Set 15 | carmen
# Processing Record 21 of Set 15 | rodrigues alves
# Processing Record 22 of Set 15 | yarovoye
# Processing Record 23 of Set 15 | stawell
# Processing Record 24 of Set 15 | lavumisa
# Processing Record 25 of Set 15 | saint paul
# Processing Record 26 of Set 15 | shibetsu
# Processing Record 27 of Set 15 | sola
# Processing Record 28 of Set 15 | san jose
# Processing Record 29 of Set 15 | nueva loja
# Processing Record 30 of Set 15 | baillif
# Processing Record 31 of Set 15 | kitzingen
# Processing Record 32 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 33 of Set 15 | ayagoz
# Processing Record 34 of Set 15 | kristinehamn
# Processing Record 35 of Set 15 | barcelos
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries into a Pandas DataFrame 
city_database_df = pd.DataFrame(city_data)
city_database_df.head(10)
# Out:
#                 City Country      Lat       Lng  Max Temp  Humidity  \
# 0        Santa Maria      BR -29.6842  -53.8069     94.86        22
# 1           Tasiilaq      GL  65.6145  -37.6368     21.36        60
# 2       Puerto Ayora      EC  -0.7393  -90.3518     82.36        84
# 3          Grindavik      IS  63.8424  -22.4338     30.67        93
# 4            Iqaluit      CA  63.7506  -68.5145     -6.29        98
# 5              Bluff      NZ -46.6000  168.3333     58.80        88
# 6  Sao Joao Da Barra      BR -21.6403  -41.0511     77.09        92
# 7            Ushuaia      AR -54.8000  -68.3000     47.82        76
# 8            Dunedin      NZ -45.8742  170.5036     58.68        95
# 9            Mataura      NZ -46.1927  168.8643     58.48        96
#
#    Cloudiness  Wind Speed Weather Description
# 0           0        6.17           clear sky
# 1          32        7.78    scattered clouds
# 2          80        5.01       broken clouds
# 3          75       19.57          light snow
# 4         100        4.34          light snow
# 5          89       14.23     overcast clouds
# 6         100        7.83     overcast clouds
# 7          75       28.77       broken clouds
# 8          97        3.87     overcast clouds
# 9          61        2.08       broken clouds

# %%
# Create the output file, CSV
output_data_file = "Weather_Database/WeatherPy_Database.csv"

#Export the city data into a CSV
city_database_df.to_csv(output_data_file, index_label = "City_ID")
